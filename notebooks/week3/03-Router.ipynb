# %% [markdown]
# Import Dependencies

# %%
from pydantic import BaseModel

from langsmith import traceable, get_current_run_tree

import instructor

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send

from langchain_core.messages import SystemMessage
from IPython.display import Image, display

from typing import Literal, Dict, Any, Annotated, List
from pydantic import Field
from operator import add

import random
import openai
import pandas as pd

from jinja2 import Template

from qdrant_client import QdrantClient
from qdrant_client import models
from qdrant_client.models import VectorParams, Distance, SparseVectorParams, Modifier, PayloadSchemaType, PointStruct, Document, Prefetch, FusionQuery

# %% [markdown]
# Query Expansion (Parallel Execution)

# %%
class State(BaseModel):
    expanded_query: List[str] = []
    retrieved_context: Annotated[List[str], add] = []
    initial_query: str = ""
    answer: str = ""
    question_relevant: bool = False
    query: str = ""
    k: int = 10

# %% [markdown]
# Query Expansion / Rewriting Node

# %%
class QueryExpandResponse(BaseModel):
    statements: List[str]

# %%
@traceable(
    name="query_expansion",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def query_expansion_node(state: State) -> dict:

    prompt_template = """You are a query expansion module in a shopping assistant. Your job is to rewrite a customer's query into distinct statements for semantic product search.

## Instructions

- Expand the question into 1-5 concise statements.
- Each statement should capture a separate product or attribute from the query.
- Use natural product-description language.
- Do not produce multiple statements that express the same intent.

## Examples

Question: "Can I get earphones for me and a waterproof speaker?"
Statements:
- "Personal earphones"
- "Waterproof speaker"

Question: "I need a warm winter jacket for hiking"
Statements:
- "Insulated winter jacket"
- "Hiking outerwear for cold weather"

Question: "Do you have any toys?"
Statements:
- "Toys"

<question>
{{ query }}
</question>
"""

    template = Template(prompt_template)

    prompt = template.render(
        query=state.initial_query
    )

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt}
        ],
        reasoning={"effort": "none"},
        response_model=QueryExpandResponse
    )

    return {
        "expanded_query": response.statements
    }

# %%
def query_expand_conditional_edges(state: State) -> dict:

    send_messages = []

    for query in state.expanded_query:
        send_messages.append(
            Send(
                "retriever_node",
                {
                    "query": query,
                    "k": state.k
                }
            )
        )

    return send_messages

# %% [markdown]
# Retriever Node

# %%
@traceable(    
name="embed_query",
    run_type="embedding",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "text-embedding-3-small"
    }
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model
    )

    current_run = get_current_run_tree()
    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens,
        }

    return response.data[0].embedding


@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retriever_node(state: State) -> dict:

    hybrid = True

    qdrant_client = QdrantClient(url="http://localhost:6333")

    query_embedding = get_embedding(state["query"])

    if hybrid:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            prefetch=[
                Prefetch(
                    query=query_embedding,
                    using="text-embedding-3-small",
                    limit=20
                ),
                Prefetch(
                    query=Document(
                        text=state["query"],
                        model="qdrant/bm25"
                    ),
                    using="bm25",
                    limit=20
                )
            ],
            query=models.RrfQuery(rrf=models.Rrf(weights=[3,1])),
            limit=state["k"]
        )
    else:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            query=query_embedding,
            using="text-embedding-3-small",
            limit=state["k"]
        )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["preprocessed_description"])
        similarity_scores.append(result.score)
        retrieved_context_ratings.append(result.payload["average_rating"])

    formatted_context = ""

    for id, chunk, rating in zip(retrieved_context_ids, retrieved_context, retrieved_context_ratings):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return {
        "retrieved_context": [formatted_context]
    }

# %% [markdown]
# Aggregator Node

# %%
class AggregatorResponse(BaseModel):
    answer: str

# %%
@traceable(
    name="generate_answer",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def aggregator_node(state: State) -> dict:

    preprocessed_context = "\n".join(state.retrieved_context)

    prompt_template = """You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

### Instructions

- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.
- The answer to the question should contain detailed information about the product and returned with detailed specification in bullet points.

### Context

{{ preprocessed_context }}

### Question

{{ question }}
"""

    template = Template(prompt_template)

    prompt = template.render(
        preprocessed_context=preprocessed_context,
        question=state.initial_query
    )

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt}
        ],
        reasoning={"effort": "none"},
        response_model=AggregatorResponse
    )

    return {
        "answer": response.answer
    }

# %% [markdown]
# User Intent Router Node

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str = Field(description="An answer to the question if the users question is not relevant to the products.")

# %%
@traceable(
    name="route_intent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def intent_router_node(state: State) -> dict:

    prompt_template = """You are a relevance router for a shopping assistant that answers questions about products in stock.

## Instructions

- Determine whether the question is about products, inventory, or purchasing.
- Questions about product features, availability, pricing, comparisons, and recommendations are relevant.
- Questions about store policies, personal advice, or unrelated topics are not relevant.

## Examples

Question: "Do you have running shoes under $100?"
Relevant: yes

Question: "What's the weather like today?"
Relevant: no - not related to products

Question: "Can you help me write an essay?"
Relevant: no - not related to products

Question: "Which laptop has the best battery life?"
Relevant: yes

Question: "What's your return policy?"
Relevant: no - about store policy, not product information

<question>
{{ query }}
</question>
"""

    template = Template(prompt_template)

    prompt = template.render(
        query=state.initial_query
    )

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt}
        ],
        reasoning={"effort": "none"},
        response_model=IntentRouterResponse
    )

    return {
        "question_relevant": response.question_relevant,
        "answer": response.answer
    }

# %%
def intent_router_conditional_edges(state: State) -> str:

    if state.question_relevant:
        return "query_expansion_node"
    else:
        return "end"

# %% [markdown]
# Graph Construction

# %%
workflow = StateGraph(State)

workflow.add_node("query_expansion_node", query_expansion_node)
workflow.add_node("retriever_node", retriever_node)
workflow.add_node("aggregator_node", aggregator_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "query_expansion_node": "query_expansion_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "query_expansion_node",
    query_expand_conditional_edges
)

workflow.add_edge("retriever_node", "aggregator_node")
workflow.add_edge("aggregator_node", END)

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state = {
    "initial_query": "Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?"
}

# %%
result = graph.invoke(initial_state)

# %%
result
# Out:
# {'expanded_query': ["Kid's tablet",
#   'Adult watch',
#   'Laptop for wife',
#   'Waterproof speaker'],
#  'retrieved_context': ['- ID: B0C4KCQB19, rating: 3.7, description: 7inch Tablet for Kids Android 11 Tablets 3GB 32GB Parental Control Children Learning Toddler Tablet Shockproof Kickstand Case, GMS Certified, Google Tableta YouTube Netflix (Pink) ★[Best Kids-Friendly Compansion ] -With parental control mode, you can create and customize profiles for kids’accounts, hand-pick content for your kids, control screen time and ensure they are browsing safe websites. These security settings can be adjusted as kids grow with content tailored to their age. ★[A Full-feature Tablet for Kids] - This kids edition tablet has built-in a high-performance quad-core processor with stable Android 11 smooth System OS, 1024x600 IPS HD display, Wifi, Bluetooth, dual camera with flash, touch screen, 3GB RAM and 32GB ROM. You can expand the storage to 256GB of SD cards for storing photos, music, videos. A more stable Wifi module and a durable battery 3000mAh will offer you a better experience. ★[Free Kids APP & Games Pre-installed ] - COLORROOM Kids Tablet comes with a safe and funny iWawa Kid\'s software free pre-installed apps for Kids learning & playing, free kids app in the kids store, you can download different apps from the Google Play store. An ideal gift for birthday, Christmas, holiday season for kids or yourself. 【Exclusive Kid-Proof Case & Tablet Kickstand 】The specially designed case protects your kid\'s tablet against dust, bumps and drops. Risk-assured, you will get a brand-new one if the android tablet is crushed when it drops from the tab. At the same time, all the features are accessible with precise cut-outs of ports, cameras. A colorful and Stable stand on the back of the case allows toddlers to go hands-free for watching videos and video chatting. 【5 Years Quality Assurance】Customer satisfaction is always our first standard. If there is any problem with the use of kids learning tablet, please feel free to contact us, we will always here help you out within 24 hours . 180-days money-back and 5 years of life time worry-free protection .\n- ID: B0BFR7JRQS, rating: 4.4, description: 2 Pack LCD Writing Tablet 12 Inch for Kids,Toys for 3 4 5 6 7 8 9 Year Old Girls Boys,LEYAOYAO Colorful Drawing Pad Doodle Board,Travel Learning Birthday Gift for 3 Age+ Toddler (Pink+Blue) Color drawing boards: We firmly believe that LEYAOYAO can make thousands of children write "I ♥ Mom" on the drawing board, then we will succeed. LCD writing tablet adopts the latest liquid crystal pressure-sensitive technology, which produces lines of different thicknesses according to the strength of your push. When boys and girls write, draw, and graffiti, different colors will appear on the drawing tablets. 2 pack sharing: 2 writing tablets 12Inch(1 Blue and 1 Pink). The electronic drawing tablet has one-key clear button, can be erased and written more than 100,000 times. magnetic learning toys for toddlers tablet.There is no mess of paper, crayons, markers or chalk at home.The key lock effectively prevents accidental clearing, and the screen can be erased when the writing pad unlocking. Multi-Purpose: our doodle board suitable for kids drawing,graffiti,painting,draft ,note taking,learning and scrawl at home ,school or travel etc.Toys for 3 4 5 6 7 8 9 years old girls boys. Lightweight and Portable: Made of high-quality plastic material, weighs only 280 grams, is easy to carry and travel in scheduler, briefcase or backpack, suitable for multiple occasions: living room, car,restaurant, plane,outdoor places. The writing tablet is waterproof and anti-fall, no need to worry about accidental dropping and liquid pouring on the screen. Best gifts: the best learning toy for kid. It can be an educational toy for preschoolers. It can be a travel toy for long drives and road trips. A parent-pick gift for kids 3+ age girl and boy on Valentine\'s day, back to school, homeschool,Easter,birthday,Children\'s Day,Thanksgiving Day, Christmas and any occasions!\n- ID: B0BZ7JHGR1, ratin ...
#   '- ID: B09VC1634J, rating: 3.9, description: woednx Smart Watch (Green Bands) smart watch smart watch smart watch smart watch smart watch\n- ID: B0C85JVZY8, rating: 3.1, description: ASWEE Smart Watch Fitness Tracker with 24/7 Heart Rate, Blood Oxygen Blood Pressure and Sleep Monitor, 1.7\'\' Full Touch 5 ATM Waterproof Smartwatch, Step Counter Watch for Women Men Kids, White 💝【Always-On Style Statement】Customize and change your smart watch display with images from your gallery. In addition get 100+ predesigned watch faces from FitCloudPro App. 💝【1.7\'\' Full Touch Color display】Do more on one screen with 320x320 pixel resolution & 350 nits brightness. Makes every glance at the watch worthwhile whether it’s Incoming calls, messages, or reminders. 💝【Multiple Fitness Modes】Whether you like high or low-intensity workouts or prefer indoors over outdoors, the Smart Watch lets you choose from a wide range of sport modes including Cricket & keeps track of your movement in real-time and supports setting specific workout goals. 💝【All-Day Health Tracking】Built-in high-precision PPG sensor to track your heart rate 24 hours a day. It can also save your resting heart rate data for 7 days to help monitor long-term heart rate changes. The blood oxygen is measured using reflective-light based sensor on the wrist. Stay calm when you experience shortage of breath, weakness or dizziness. Now check the status of your blood oxygen levels conveniently on your smartwatch. 💝【Intelligent Notification】You can get call, SMS text and SNS messages including Facebook,Twitter, WhatsApp, Linkedin, Messenger and more when the smart watches are synced to the smartphone. The smart watches receives messages, calls, and app notifications by getting a vibration alert on the watches device, also can answer/make call or answer text with it. 💝【Ultra-Long Battery Life】Global upgrades of low-power AI algorithms extend the battery life of the smart watch. Charge instantly with the easy magnetic charging cable. Regular use Up to 7 days, standby for 30 days. 💝【Wide Compatibility】ASWEE smartwatch uses a low-power Bluetooth 5.3 chip, making the device\'s transmission speed faster and the connection more stable. Compatible with iOS 9.0, Android 4.4 and above devices. 💝【5ATM water resistance】Track your movements and record your achievements with your smart watch, which supports 5ATM water resistance - up to 50m underwater. Wearing your smartwatch while Swimming or chilling in the pool was never this easy.\n- ID: B0B9FHQSMC, rating: 4.0, description: Smart Watch for Men Women Fitness: Call Receive/Dial Touch Screen Waterproof Swimming Smartwatch for Android iOS Phones Sport Digital Watches Activity Tracker Heart Rate Sleep Monitor Step Counter Smart watches touchscreen with Sleep Heart Rate Monitor: Adopting advanced latest built-in optical sensor, health watches for women men can monitor your heart rate,blood pressure,blood oxygen.Smart watch for android phones text and call bluetooth can track your sleep status all day,analyze your sleep quality(deep sleep,light sleep and wake up time)which can help you better understand your health and make reasonable adjustment on your life-style Ios android smart watch text and call bluetooth Notifications: It\'s a smartwatch that allows you to answer or dial calls anywhere, anytime. The call function is connected to the watch via Bluetooth and you can choose to turn it on or off in the settings. Also, the watch will vibrate to remind you when your phone receives the messages or App notifications (Facebook, WhatsApp, Twitter, etc). Never miss any important notification. Exercise watches for men woman & 30 Sport Modes: Elegant calorie counter watch accurate track step,distance,calorie.Step counter for walking watch support 30 sport mode:walk,run,swim,yoga,hiking watch etc to give you more detailed insights into whole day activity.Water resistant watch is IP67 waterproof,you can wear it when swim and record various data.Pedometer watch wo ...
#   '- ID: B0BZ8KCB12, rating: 4.6, description: Laptop Bag for Women 15.6 Inch Laptop Tote Bag Leather Work Bag Waterproof Womens Briefcase Business Office Computer Tote Bag Large Capacity Handbag Shoulder Bag Black 【High-quality Laptop Bag】This laptop bag for women is made of wear-resistant & waterproof PU leather with high-density polyester lining. The bottom features 4 metal feet, making this women work bag stand upright and scratch-resistant. Equipped with smooth zipper, sturdy handle and golden metal hardware, make the laptop purse more durable. 【Multi-pocket Laptop Tote】1 well-padded laptop compartment, 1 tablet compartment, 1 middle zipper compartment, 1 wall zipper pocket, 2 pen slots, 2 slip pockets, 2 side elastic pockets, 2 open compartments, 1 built-in key ring and 1 front magnetic pocket. Large capacity to make your daily stuff well organized. 【Work Tote Bag Size】The size of the briefcase for women is 16.5" L * 5.1" W * 11.5" H, can easy to fit most 13-15.6 inches laptop. Weight: 2.2 lb. Handle drop: 7.1". Perfect laptop tote bag for women is an great partner for work, shopping, dating. 【Versatile Tote Bag】Professional work bags for women comes with comfortable handle and detachable & adjustable shoulder strap, can be carried in different ways. Practical computer bag can be used as as a handbag, laptop bag, teacher tote bag, ladies briefcase, college shoulder bag and business office work bag. 【Perfect Gift Choice】Combined of practicality and fashion, this laptop tote bag is an ideal gift choice for mother, girlfriend, wife, friends,sisters, yourself on Mother\'s Day, Valentine\'s Day, Christmas, birthdays, anniversaries, Thanksgiving Day or other holidays. THIS ITEM IS NOT INTENDED FOR USE BY CHILDREN 12 AND UNDER\n- ID: B09SFZVCZT, rating: 4.2, description: HP 2022 Newest 15.6" HD Light-Weight Laptop for Home use and Student, 4-Core Intel i3-1125G4(Up to 3.7GHz,Beat i7-8565U), 16GB RAM, 512GB SSD, HDMI, Webcam, WiFi, Fast Charge, Numpad,w/GM Accessories 【15.6" HD anti-glare micro-edge Display】15.6-inch diagonal HD BrightView micro-edge anti-glare. With virtually no bezel encircling the display, an ultra-wide viewing experience provides for seamless multi-monitor set-ups. 【11th Gen Intel Core i3-1125G4 】2GHz base frequency, up to 3.7 GHz with Intel Turbo Boost Technology, The 11th gen dual-core laptop brings the perfect combination of features to make you unstoppable. This is an ideal home office laptop to get things done fast with high performance, instant responsiveness and best-in-class connectivity. 【Upgraded to 16GB DDR4 RAM】Substantial high-bandwidth RAM to smoothly run your games and photo- and video-editing applications, as well as multiple programs and browser tabs all at once. 【Upgraded storage to 512GB SSD】Provides massive storage space for huge files, so that you can store important digital data and work your way through it with ease. It gives you enormous space to save all of your files. 【Windows 11 Home in S mode】You may switch to regular windows 11: Press "Start button" bottom left of the screen; Select "Settings" icon above "power" icon;Select Update & Security and Activation, then Go to Store; Select "Get" option under "Switch out of S mode"; Hit Install. (If you also see an "Upgrade your edition of Windows" section, be careful not to click the "Go to the Store" link that appears there.)\n- ID: B09ZQTHHPZ, rating: 4.6, description: Laptop Bag for Women 15.6 inch Laptop Tote Bag Waterproof Leather Work Bag Large Capacity Computer Tote Bag Professional Office Business Briefcase Lightweight Travel Handbag Shoulder Bag, Brown 【MULTIPLE POCKETS WORK TOTE】Laptop tote bag has lots of pockets to keep your items organized. Main 8 sections including 1 classy padded pocket for 15.6inch laptop, 2 large open pockets for documents/books, 1 middle zip pocket for your private items, 2 slip pockets for chargers and mouse, 2 pen pockets to avoid losing pens, 1 internal zipper pocket for your wallet or earbuds, 2 ela ...
#   '- ID: B0CF589N1T, rating: 4.4, description: LFS Portable Bluetooth Shower Speaker, Waterproof Outdoor Wireless Speaker, Ultra-Long Play Time 15 Hours, TWS Pairing, Suitable for Home, Pool, Beach, Boating, Hiking, Camping TWS Dual Stereo: updated sound with 10W high stereo power through two Bluetooth speakers connected together! speakers bluetooth wireless has crystal clear sound and rich, full bass, you will be blown away by the HD quality sound Bluetooth version 5.0: Portable wireless Bluetooth speaker uses advanced Bluetooth technology to provide fast connectivity as well as greater wireless range and more stable Bluetooth connection for all Bluetooth devices. Such as cell phones, tablets, laptops, computers, Macbooks, MP3 players, etc Super long playing time: LFS portable Bluetooth speaker has a built-in 1500mAh rechargeable lithium battery, Bluetooth speaker can be used up to 15 hours, so you can enjoy music from morning to night, never stop Waterproof and Dustproof: Bluetooth waterproof outdoor speaker ensures dustproof, waterproof, shockproof, rainproof and snowproof, perfect for hiking, rafting, boating, swimming, kayaking and showering, etc. Bring our Bluetooth speaker and let it be your good companion also let you be a travel rocker Lightweight and portable small size: portable wireless bluetooth speaker wears a lanyard and has a built-in microphone that makes it easy to take calls via bluetooth mode. bluetooth speakers modern design makes it a great gift choice for any occasion, at a friends party, going camping outdoors with family and friends, etc\n- ID: B0CHWC1CD6, rating: 4.9, description: Bluetooth Speakers, IPX7 Waterproof Wireless Speaker with Colorful Flashing Lights, Portable Bluetooth Speaker with Bluetooth 5.3,Built-in Mic hands-free calling,Suitable for Travel, Home and Outdoors Immersive Sound Experience: This bluetooth speakers portable wireless delivers high-frequency sound that is clear and bright, midrange that is crisp and clean, and low frequencies that are low and powerful and full sounding through 2 drivers and our proprietary technology. Delivers deep, clear, immersive audio at home or on the go. Great for gaming, music and movie playback. This bluetooth speaker is sure to be a great choice for a gift for women or men. Vibrant Lighting Effects: The wireless LED portable speaker not only comes with speakers, but also unique night themed lights which offer different color changing themes. Portable speaker bluetooth the dynamic multi-color light show synchronized with the beat of the music brings a new level of excitement to your party, just press the light button to easily customize the light effects to suit your preferences. The fading lights will really bring the party atmosphere to you as you enjoy the music. Bluetooth 5.3 and 12H Playback Time: The Blue tooth speaker has the latest Bluetooth 5.3 chip built in to ensure fast pairing and a stable connection. The speakers bluetooth wireless lasts all day and can play for up to 12 hours per charge. You can turn on/off the multi-colored light by clicking the "light button" on the surface to meet your needs and extend battery life. Actual playback time varies depending on volume, audio content and usage. IPX7 Waterproof and Compact: The waterproof bluetooth speaker is splash-proof, rain-proof, making it suitable for use in the shower as a waterproof speaker, at the pool or beach, or even in the rain as a waterproof Bluetooth speaker. However, please do not put this wireless speaker directly into water. The speaker is lightweight and easy to carry, you can put it in your backpack or attach it to your bike. This outdoor speakers bluetooth waterproof is your ultimate portable sound companion! You will Receive: Wireless speakers with bluetooth x 1, Portable Lanyard x 1, Type-C Charging Cable x 1, Instruction Manual x 1. wireless bluetooth speaker built-in microphone for hands-free calling, you can also use the AUX jack to play music from other device ...
#  'initial_query': 'Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?',
#  'answer': 'Here are suitable options from the available products for each of your needs:\n\n- **Tablet for your kid:**\n  - **B0C4KCQB19** — 7-inch Kids Tablet\n  - Android 11 with **3GB RAM / 32GB ROM**\n  - **Parental control mode** to manage profiles, screen time, and safe browsing\n  - **1024x600 IPS HD display**, Wi‑Fi, Bluetooth, dual camera with flash\n  - **Expandable storage up to 256GB** via SD card\n  - **3000mAh battery**\n  - Includes a **kid-proof shockproof case** with a built-in kickstand\n  - Google certified and supports apps like **YouTube** and **Netflix**\n\n- **Watch for you:**\n  - **B0C7QXCV62** — Smart Watch for Men Women with Alexa Built-in\n  - **1.95" HD screen**\n  - Supports **answering/making calls** and message notifications\n  - Tracks **heart rate, blood oxygen, stress, sleep**, and activity\n  - **100+ sports modes**\n  - **IP68 waterproof**\n  - Battery life up to **7–10 days of daily use** and up to **30 days standby**\n  - Compatible with **Android and iOS**\n\n- **Laptop for your wife:**\n  - **B0BZ8KCB12** — 15.6-inch Laptop Bag for Women\n  - **Waterproof PU leather** with a professional tote/briefcase design\n  - Fits **13–15.6 inch laptops**\n  - Multiple compartments including a **padded laptop compartment**, tablet compartment, pen slots, slip pockets, side pockets, and front pocket\n  - **Detachable and adjustable shoulder strap** for multiple carry styles\n  - Good for **work, shopping, office, college, and travel**\n\n- **Waterproof speaker:**\n  - **B0CHWC1CD6** — Bluetooth Speaker\n  - **IPX7 waterproof** portable wireless speaker\n  - **Bluetooth 5.3** for stable connection\n  - Up to **12 hours playback time**\n  - Built-in mic for **hands-free calling**\n  - Includes **colorful flashing lights** and is suitable for travel, home, and outdoors\n\nIf you want, I can also help narrow these down by budget, size, or brand preference.',
#  'question_relevant': True}

# %%
print(result["answer"])
# Out:
# Here are suitable options from the available products for each of your needs:
#
# - **Tablet for your kid:**
#   - **B0C4KCQB19** — 7-inch Kids Tablet
#   - Android 11 with **3GB RAM / 32GB ROM**
#   - **Parental control mode** to manage profiles, screen time, and safe browsing
#   - **1024x600 IPS HD display**, Wi‑Fi, Bluetooth, dual camera with flash
#   - **Expandable storage up to 256GB** via SD card
#   - **3000mAh battery**
#   - Includes a **kid-proof shockproof case** with a built-in kickstand
#   - Google certified and supports apps like **YouTube** and **Netflix**
#
# - **Watch for you:**
#   - **B0C7QXCV62** — Smart Watch for Men Women with Alexa Built-in
#   - **1.95" HD screen**
#   - Supports **answering/making calls** and message notifications
#   - Tracks **heart rate, blood oxygen, stress, sleep**, and activity
#   - **100+ sports modes**
#   - **IP68 waterproof**
#   - Battery life up to **7–10 days of daily use** and up to **30 days standby**
#   - Compatible with **Android and iOS**
#
# - **Laptop for your wife:**
#   - **B0BZ8KCB12** — 15.6-inch Laptop Bag for Women
#   - **Waterproof PU leather** with a professional tote/briefcase design
#   - Fits **13–15.6 inch laptops**
#   - Multiple compartments including a **padded laptop compartment**, tablet compartment, pen slots, slip pockets, side pockets, and front pocket
#   - **Detachable and adjustable shoulder strap** for multiple carry styles
#   - Good for **work, shopping, office, college, and travel**
#
# - **Waterproof speaker:**
#   - **B0CHWC1CD6** — Bluetooth Speaker
#   - **IPX7 waterproof** portable wireless speaker
#   - **Bluetooth 5.3** for stable connection
#   - Up to **12 hours playback time**
#   - Built-in mic for **hands-free calling**
#   - Includes **colorful flashing lights** and is suitable for travel, home, and outdoors
#
# If you want, I can also help narrow these down by budget, size, or brand preference.

# %%
initial_state = {
    "initial_query": "How many times should I be walking my dog per day?"
}

# %%
result = graph.invoke(initial_state)

# %%
result
# Out:
# {'retrieved_context': [],
#  'initial_query': 'How many times should I be walking my dog per day?',
#  'answer': 'This question is about pet care advice, not products, inventory, or purchasing.',
#  'question_relevant': False}
